# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os as os
import warnings
warnings.filterwarnings('ignore')

# %%
Reorg_folder = "Reorg_Energy/"
Gaussian_folder = "Gaussian_outputs/"
show = True

if show:

    print("Reorg files")
    files = [file.name for file in os.scandir(Reorg_folder)]
    files.sort()
    for file in files:
        print(file)

    print("\n")

    print("Gaussian outputs")
    files = [file.name for file in os.scandir(Gaussian_folder)]
    files.sort()
    for file in files:
        print(file)
# Out:
# Reorg files
# Benzene_Conj_0_C0S0_C-1S0
# Benzene_Conj_0_C0S0_C0S1
# Benzene_Conj_0_C0S0_C1S0
# Benzene_Conj_1_C0S0_C-1S0
# Benzene_Conj_1_C0S0_C0S1
# Benzene_Conj_1_C0S0_C1S0
# Benzene_Conj_2_C0S0_C-1S0
# Benzene_Conj_2_C0S0_C0S1
# Benzene_Conj_2_C0S0_C1S0
# Benzene_Conj_3_C0S0_C-1S0
# Benzene_Conj_3_C0S0_C0S1
# Benzene_Conj_3_C0S0_C1S0
# Benzene_Conj_4_C0S0_C-1S0
# Benzene_Conj_4_C0S0_C0S1
# Benzene_Conj_4_C0S0_C1S0
# Benzene_Conj_5_C0S0_C-1S0
# Benzene_Conj_5_C0S0_C0S1
# Benzene_Conj_5_C0S0_C1S0
# Circulene_0_C0S0_C-1S0
# Circulene_0_C0S0_C1S0
# Circulene_1_C0S0_C-1S0
# Circulene_1_C0S0_C1S0
# Common_Moeties_0_C0S0_C-1S0
# Common_Moeties_0_C0S0_C1S0
# Common_Moeties_15_C0S0_C1S0
# Common_Moeties_16_C0S0_C1S0
# Common_Moeties_18_C0S0_C1S0
# Common_Moeties_19_C0S0_C1S0
# Common_Moeties_6_C0S0_C1S0
# Common_Moeties_7_C0S0_C1S0
# IDTBx_1_C-1S0_C0S0
# Non-cov-phenyl-N_0_C0S0_C-1S0
# Non-cov-phenyl-N_0_C0S0_C0S1
# Non-cov-phenyl-N_0_C0S0_C1S0
# Non-cov-phenyl-N_1_C0S0_C-1S0
# Non-cov-phenyl-N_1_C0S0_C0S1
# Non-cov-phenyl-N_1_C0S0_C1S0
# Non-cov-phenyl-N_2_C0S0_C-1S0
# Non-cov-phenyl-N_2_C0S0_C0S1
# Non-cov-phenyl-N_2_C0S0_C1S0
# Non-cov-phenyl-N_3_C0S0_C-1S0
# Non-cov-phenyl-N_3_C0S0_C0S1
# Non-cov-phenyl-N_3_C0S0_C1S0
# Non-cov-phenyl-N_4_C0S0_C-1S0
# Non-cov-phenyl-N_4_C0S0_C0S1
# Non-cov-phenyl-N_4_C0S0_C1S0
# Phenyls_0_C0S0_C-1S0
# Phenyls_0_C0S0_C0S1
# Phenyls_0_C0S0_C1S0
# Phenyls_1_C0S0_C-1S0
# Phenyls_1_C0S0_C0S1
# Phenyls_1_C0S0_C1S0
# Phenyls_2_C0S0_C-1S0
# Phenyls_2_C0S0_C0S1
# Phenyls_2_C0S0_C1S0
# Phenyls_3_C0S0_C-1S0
# Phenyls_3_C0S0_C0S1
# Phenyls_3_C0S0_C1S0
# Phenyls_4_C0S0_C-1S0
# Phenyls_4_C0S0_C0S1
# Phenyls_4_C0S0_C1S0
# benzene_conj_0_C0S0_C-1S0
# conjugated_carbonyls_0_C-1S0_C-2S0
# conjugated_carbonyls_0_C0S0_C-1S0
# conjugated_carbonyls_0_C0S0_C-2S0
# conjugated_carbonyls_1_C-1S0_C-2S0
# conjugated_carbonyls_1_C-2S0_C-3S0
# conjugated_carbonyls_1_C0S0_C-1S0
# conjugated_carbonyls_1_C0S0_C-2S0
# conjugated_carbonyls_1_C0S0_C-3S0
# conjugated_carbonyls_2_C-1S0_C-2S0
# conjugated_carbonyls_2_C0S0_C-1S0
# conjugated_carbonyls_2_C0S0_C-2S0
# conjugated_carbonyls_3_C-1S0_C-2S0
# conjugated_carbonyls_3_C-2S0_C-3S0
# conjugated_carbonyls_3_C0S0_C-1S0
# conjugated_carbonyls_3_C0S0_C-2S0
# conjugated_carbonyls_3_C0S0_C-3S0
# phenothiazine-pyrene_0_C0S0_C0S1
# phenothiazine-pyrene_0_C0S0_C0S2
# phenothiazine-pyrene_0_C0S1_C0S2
# phenothiazine-pyrene_1_C0S1_C0S2
# phenothiazine-pyrene_2_C0S0_C1S0
# phenothiazine-pyrene_2_C0S1_C0S2
# phenothiazine-pyrene_3_C0S0_C0S2
# pyrene_0_C0S0_C-1S0
# pyrene_0_C1S0_C0S1
#
#
# Gaussian outputs
# Benzene_Conj_0_C-1S0.csv
# Benzene_Conj_0_C0S0.csv
# Benzene_Conj_0_C0S1.csv
# Benzene_Conj_0_C1S0.csv
# Benzene_Conj_1_C-1S0.csv
# Benzene_Conj_1_C0S1.csv
# Benzene_Conj_1_C1S0.csv
# Benzene_Conj_2_C-1S0.csv
# Benzene_Conj_2_C0S1.csv
# Benzene_Conj_2_C1S0.csv
# Benzene_Conj_3_C-1S0.csv
# Benzene_Conj_3_C0S1.csv
# Benzene_Conj_3_C1S0.csv
# Benzene_Conj_4_C-1S0.csv
# Benzene_Conj_4_C0S1.csv
# Benzene_Conj_4_C1S0.csv
# Benzene_Conj_5_C-1S0.csv
# Benzene_Conj_5_C0S1.csv
# Benzene_Conj_5_C1S0.csv
# Circulene_0_C-1S0.csv
# Circulene_0_C1S0.csv
# Circulene_1_C-1S0.csv
# Circulene_1_C1S0.csv
# Common_Moeties_0_C-1S0.csv
# Common_Moeties_0_C1S0.csv
# Common_Moeties_10_C1S0.csv
# Common_Moeties_15_C1S0.csv
# Common_Moeties_16_C1S0.csv
# Common_Moeties_17_C1S0.csv
# Common_Moeties_18_C1S0.csv
# Common_Moeties_19_C1S0.csv
# Common_Moeties_1_C1S0.csv
# Common_Moeties_2_C1S0.csv
# Common_Moeties_4_C1S0.csv
# Common_Moeties_5_C1S0.csv
# Common_Moeties_6_C1S0.csv
# Common_Moeties_7_C1S0.csv
# Common_Moeties_8_C1S0.csv
# Common_Moeties_9_C1S0.csv
# IDTBx_1_C0S0.csv
# Non-cov-phenyl-N_0_C-1S0.csv
# Non-cov-phenyl-N_0_C0S1.csv
# Non-cov-phenyl-N_0_C1S0.csv
# Non-cov-phenyl-N_1_C-1S0.csv
# Non-cov-phenyl-N_1_C0S1.csv
# Non-cov-phenyl-N_1_C1S0.csv
# Non-cov-phenyl-N_2_C-1S0.csv
# Non-cov-phenyl-N_2_C0S1.csv
# Non-cov-phenyl-N_2_C1S0.csv
# Non-cov-phenyl-N_3_C-1S0.csv
# Non-cov-phenyl-N_3_C0S1.csv
# Non-cov-phenyl-N_3_C1S0.csv
# Non-cov-phenyl-N_4_C-1S0.csv
# Non-cov-phenyl-N_4_C0S1.csv
# Non-cov-phenyl-N_4_C1S0.csv
# Phenyls_0_C-1S0.csv
# Phenyls_0_C0S1.csv
# Phenyls_0_C1S0.csv
# Phenyls_1_C-1S0.csv
# Phenyls_1_C0S1.csv
# Phenyls_1_C1S0.csv
# Phenyls_2_C-1S0.csv
# Phenyls_2_C0S1.csv
# Phenyls_2_C1S0.csv
# Phenyls_3_C-1S0.csv
# Phenyls_3_C0S1.csv
# Phenyls_3_C1S0.csv
# Phenyls_4_C-1S0.csv
# Phenyls_4_C0S1.csv
# Phenyls_4_C1S0.csv
# benzene_conj_0_C-1S0.csv
# conjugated_carbonyls_0_C-1S0.csv
# conjugated_carbonyls_0_C-2S0.csv
# conjugated_carbonyls_0_C-3S0.csv
# conjugated_carbonyls_1_C-1S0.csv
# conjugated_carbonyls_1_C-2S0.csv
# conjugated_carbonyls_1_C-3S0.csv
# conjugated_carbonyls_2_C-1S0.csv
# conjugated_carbonyls_2_C-2S0.csv
# conjugated_carbonyls_2_C-3S0.csv
# conjugated_carbonyls_3_C-1S0.csv
# conjugated_carbonyls_3_C-2S0.csv
# conjugated_carbonyls_3_C-3S0.csv
# conjugated_carbonyls_4_C-1S0.csv
# phenothiazine-pyrene_0_C-1S0.csv
# phenothiazine-pyrene_0_C0S1.csv
# phenothiazine-pyrene_0_C0S2.csv
# phenothiazine-pyrene_0_C1S0.csv
# phenothiazine-pyrene_1_C0S2.csv
# phenothiazine-pyrene_1_C1S0.csv
# phenothiazine-pyrene_2_C0S2.csv
# phenothiazine-pyrene_2_C1S0.csv
# phenothiazine-pyrene_3_C0S1.csv
# phenothiazine_0_C-1S0.csv
# phenothiazine_0_C0S0.csv
# pyrene_0_C-1S0.csv
# pyrene_0_C0S1.csv

# %%
Serial_and_info = {
    
    #name         : [Serial,Group,Conjugation,Non-Covalent]
    
    "Benzene"     : ["Benzene_Conj_0","Oligoacene",True,False],
    "Naphthalene" : ["Benzene_Conj_1","Oligoacene",True,False],
    "Anthracene"  : ["Benzene_Conj_2","Oligoacene",True,False],
    "Tetracene"   : ["Benzene_Conj_3","Oligoacene",True,False],
    "Pentacene"   : ["Benzene_Conj_4","Oligoacene",True,False],
    "Hexacene"    : ["Benzene_Conj_5","Oligoacene",True,False],
    
    "Biphenyl"        : ["Phenyls_0","Phenyls",True,False],
    "p-Terphenyl"     : ["Phenyls_1","Phenyls",True,False],
    "p-Quarterphenyl" : ["Phenyls_2","Phenyls",True,True],
    "p-Quinquephenyl" : ["Phenyls_3","Phenyls",True,False],
    "p-Sexiphenyl"    : ["Phenyls_4","Phenyls",True,False],
    
    "[5]circulene (corannulene)" : ["Circulene_0","Circulene",True,False],
    "[6]circulene (coronene)"    : ["Circulene_1","Circulene",True,False],
    
    "Quarterphenyl"                   : ["Non-cov-phenyl-N_0",'Non-Cov Phenyls',False,True],
    "Quarterphenyl-1NH"               : ["Non-cov-phenyl-N_1",'Non-Cov Phenyls',False,True],
    "Quarterphenyl-2NH (Adjacent)"    : ["Non-cov-phenyl-N_2",'Non-Cov Phenyls',False,True],
    "Quarterphenyl-2NH (Across)"      : ["Non-cov-phenyl-N_3",'Non-Cov Phenyls',False,True],
    "Quarterphenyl-3NH"               : ["Non-cov-phenyl-N_4",'Non-Cov Phenyls',False,True],
    
    "Phenothiazine-Pyrene 2" : ["phenothiazine-pyrene_2","Phenothiazine-Pyrene",False,False],
    
    #"PTO"   : ["conjugated_carbonyls_0","Conjugated Carbonyls",False,False],
    #"PhenQ" : ["conjugated_carbonyls_1","Conjugated Carbonyls",False,False],
    #"BDTQ"  : ["conjugated_carbonyls_2","Conjugated Carbonyls",False,False],
    #"PQ"    : ["conjugated_carbonyls_3","Conjugated Carbonyls",False,False],
    
}


MultiIndex_rows = [
#Stores the families/groups that the molecules are in
    
    ('Oligoacene','Benzene'),
    ('Oligoacene','Naphthalene'),
    ('Oligoacene','Anthracene'),
    ('Oligoacene','Tetracene'),
    ('Oligoacene','Pentacene'),
    ('Oligoacene','Hexacene'),
    
    ('Phenyls','Biphenyl'),
    ('Phenyls','p-Terphenyl'),
    ('Phenyls','p-Quarterphenyl'),
    ('Phenyls','p-Quinquephenyl'),
    ('Phenyls','p-Sexiphenyl'),
    
    ('Circulene','[5]circulene (corannulene)'),
    ('Circulene','[6]circulene (coronene)'),
    
    ('Non-Cov Phenyls','Quarterphenyl'),
    ('Non-Cov Phenyls','Quarterphenyl-1NH'),
    ('Non-Cov Phenyls','Quarterphenyl-2NH (Adjacent)'),
    ('Non-Cov Phenyls','Quarterphenyl-2NH (Across)'),
    ('Non-Cov Phenyls','Quarterphenyl-3NH'),
    
    ('Phenothiazine-Pyrene','Phenothiazine-Pyrene 2'),
    
    #('Conjugated Carbonyls','conjugated_carbonyls_0'),
    #('Conjugated Carbonyls','conjugated_carbonyls_1'),
    #('Conjugated Carbonyls','conjugated_carbonyls_2'),
    #('Conjugated Carbonyls','conjugated_carbonyls_3'),
    
    

]


MultiIndex_columns = [
#Stores the families/groups that the molecules are in
    
    ('Reorg Cation','Low_freq'),
    ('Reorg Cation','Mid_freq'),
    ('Reorg Cation','High_freq'),
    ('Reorg Cation','Total'),
    
    ('Reorg Anion','Low_freq'),
    ('Reorg Anion','Mid_freq'),
    ('Reorg Anion','High_freq'),
    ('Reorg Anion','Total'),

    ('Reorg S1','Low_freq'),
    ('Reorg S1','Mid_freq'),
    ('Reorg S1','High_freq'),
    ('Reorg S1','Total'),
    
    ('Molecule Background','N_atoms'),
    ('Molecule Background','Molecular Mass'),
    ('Molecule Background','Homo Energy'),
    ('Molecule Background','Molecular Energy'),
    ('Molecule Background','Dipole Moment'),
    ('Molecule Background','Excited State Energy'),
    ('Molecule Background','Oscillator Strength'),
    
    ('Investigation','Conjugation'),
    ('Investigation','Non-Covalent')
    

]



multi_index_rows = pd.MultiIndex.from_tuples(MultiIndex_rows, names = ["Molecular Group","Molecule"])
multi_index_columns = pd.MultiIndex.from_tuples(MultiIndex_columns)

# %%
def Database_construct(Instructions, multi_index_rows, multi_index_columns):
    Database = pd.DataFrame(index = multi_index_rows, columns = multi_index_columns)
    Database.head()
    #for i in range(0,1):
    for i in range(0,len(Instructions)):        
        Mol_name = list(Instructions.keys())[i]
        Mol_serial = Instructions[Mol_name][0]
        Mol_group = Instructions[Mol_name][1]
        Conjugation = Instructions[Mol_name][2]
        NonCov = Instructions[Mol_name][3]


        
#Units 
        cmtoEv = 1.24e-4
        
#Extracting total reorg data
#Cation
        try:
            Cation = pd.read_csv(Reorg_folder+Mol_serial+"_"+"C0S0_C1S0", usecols=['Frequencies', 'Displacement', 'Reorg Energy'])
            Cation_low = Cation[Cation['Frequencies']<500]["Reorg Energy"].sum()*cmtoEv
            Cation_mid = Cation[Cation['Frequencies']<2000][Cation['Frequencies']>=500]["Reorg Energy"].sum()*cmtoEv
            Cation_high = Cation[Cation['Frequencies']>=2000]["Reorg Energy"].sum()*cmtoEv
            Cation_total = Cation["Reorg Energy"].sum()*cmtoEv
        except:
            Cation_low = float('NaN')
            Cation_mid = float('NaN')
            Cation_high = float('NaN')
            Cation_total = float('NaN')
        
        
        try:
            Cation_Gauss = pd.read_csv(Gaussian_folder+Mol_serial+"_"+"C1S0.csv")
            n_atoms = int(Cation_Gauss["n_atoms"])
            molecular_mass = float(Cation_Gauss["molecular_mass"])
            homo_energy = float(Cation_Gauss["homo_energy"])
            scf_energy = float(Cation_Gauss["scf_energy"])
            dipole_moment = np.array(Cation_Gauss["dipole_moment"])[0]
            excited_state_energy = np.array(Cation_Gauss["excited_state_energy"])[0]*cmtoEv
            oscillator_strength = np.array(Cation_Gauss["oscillator_strength"])[0]
        except:
            n_atoms = float('NaN')
            molecular_mass = float('NaN')
            homo_energy = float('NaN')
            scf_energy = float('NaN')
            dipole_moment = float('NaN')
            excited_state_energy = float('NaN')
            oscillator_strength = float('NaN')
 
    
#Anion
        try:
            Anion = pd.read_csv(Reorg_folder+Mol_serial+"_"+"C0S0_C-1S0", usecols=['Frequencies', 'Displacement', 'Reorg Energy'])
            Anion_low = Anion[Anion['Frequencies']<500]["Reorg Energy"].sum()*cmtoEv
            Anion_mid = Anion[Anion['Frequencies']<2000][Anion['Frequencies']>=500]["Reorg Energy"].sum()*cmtoEv
            Anion_high = Anion[Anion['Frequencies']>=2000]["Reorg Energy"].sum()*cmtoEv
            Anion_total = Anion["Reorg Energy"].sum()*cmtoEv
            
        except:
            Anion_low = float('NaN')
            Anion_mid = float('NaN')
            Anion_high = float('NaN')
            Anion_total = float('NaN')

            
        try:
            Anion_Gauss = pd.read_csv(Gaussian_folder+Mol_serial+"_"+"C-1S0.csv")
            n_atoms = int(Anion_Gauss["n_atoms"])
            molecular_mass = float(Anion_Gauss["molecular_mass"])
            homo_energy = float(Anion_Gauss["homo_energy"])
            scf_energy = float(Anion_Gauss["scf_energy"])
            dipole_moment = np.array(Anion_Gauss["dipole_moment"])[0]
            excited_state_energy = np.array(Anion_Gauss["excited_state_energy"])[0]*cmtoEv
            oscillator_strength = np.array(Anion_Gauss["oscillator_strength"])[0]
        except:
            pass

#Excited

        try:
            Excited = pd.read_csv(Reorg_folder+Mol_serial+"_"+"C0S0_C0S1", usecols=['Frequencies', 'Displacement', 'Reorg Energy'])
            Excited_low = Excited[Excited['Frequencies']<500]["Reorg Energy"].sum()*cmtoEv
            Excited_mid = Excited[Excited['Frequencies']<2000][Excited['Frequencies']>=500]["Reorg Energy"].sum()*cmtoEv
            Excited_high = Excited[Excited['Frequencies']>=2000]["Reorg Energy"].sum()*cmtoEv
            Excited_total = Excited["Reorg Energy"].sum()*cmtoEv
        except:
            Excited_low = float('NaN')
            Excited_mid = float('NaN')
            Excited_high = float('NaN')
            Excited_total = float('NaN')

        try:
            Excited_Gauss = pd.read_csv(Gaussian_folder+Mol_serial+"_"+"C0S1.csv")
            n_atoms = int(Excited_Gauss["n_atoms"])
            molecular_mass = float(Excited_Gauss["molecular_mass"])
            homo_energy = float(Excited_Gauss["homo_energy"])
            scf_energy = float(Excited_Gauss["scf_energy"])
            dipole_moment = np.array(Excited_Gauss["dipole_moment"])[0]
            excited_state_energy = np.array(Excited_Gauss["excited_state_energy"])[0]*cmtoEv
            oscillator_strength = np.array(Excited_Gauss["oscillator_strength"])[0]
        except:
            pass
  
            
        #Extracting gaussian information
        


        Database.loc[Mol_group,Mol_name] = [Cation_low, Cation_mid, Cation_high, Cation_total,\
                                            Anion_low, Anion_mid, Anion_high, Anion_total,\
                                            Excited_low, Excited_mid, Excited_high, Excited_total,\
                                            n_atoms, molecular_mass, homo_energy, scf_energy, dipole_moment,\
                                            excited_state_energy, oscillator_strength,\
                                            Conjugation, NonCov]

        
    return Database

# %%
Database = 0
Database = Database_construct(Serial_and_info, multi_index_rows, multi_index_columns)
Database
# Out:
#                                                   Reorg Cation             \
#                                                       Low_freq   Mid_freq
# Molecular Group      Molecule
# Oligoacene           Benzene                                 0   0.300328
#                      Naphthalene                             0   0.186732
#                      Anthracene                       1.24e-05   0.140839
#                      Tetracene                       0.0006696    0.11501
#                      Pentacene                       0.0020336    0.09486
#                      Hexacene                        0.0031496  0.0794716
# Phenyls              Biphenyl                         0.046934   0.216975
#                      p-Terphenyl                      0.047306   0.187686
#                      p-Quarterphenyl                 0.0472812   0.163841
#                      p-Quinquephenyl                 0.0434744   0.144373
#                      p-Sexiphenyl                     0.040052   0.127832
# Circulene            [5]circulene (corannulene)      0.0387624   0.156699
#                      [6]circulene (coronene)         0.0196044   0.110596
# Non-Cov Phenyls      Quarterphenyl                   0.0472812   0.163841
#                      Quarterphenyl-1NH               0.0452228   0.165168
#                      Quarterphenyl-2NH (Adjacent)    0.0447516   0.151726
#                      Quarterphenyl-2NH (Across)      0.0467232   0.156872
#                      Quarterphenyl-3NH               0.0484964   0.145539
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2           0.025172  0.0729492
#
#                                                                          \
#                                                    High_freq      Total
# Molecular Group      Molecule
# Oligoacene           Benzene                       0.0010168   0.301345
#                      Naphthalene                   0.0007812   0.187513
#                      Anthracene                    0.0005208   0.141372
#                      Tetracene                     0.0004588   0.116138
#                      Pentacene                      0.000434  0.0973276
#                      Hexacene                        0.00031  0.0829312
# Phenyls              Biphenyl                      0.0010292   0.264938
#                      p-Terphenyl                   0.0011408   0.236133
#                      p-Quarterphenyl                0.000992   0.212114
#                      p-Quinquephenyl               0.0010416   0.188889
#                      p-Sexiphenyl                  0.0007812   0.168665
# Circulene            [5]circulene (corannulene)    0.0006324   0.196094
#                      [6]circulene (coronene)       0.0011408   0.131341
# Non-Cov Phenyls      Quarterphenyl                  0.000992   0.212114
#                      Quarterphenyl-1NH             0.0009796    0.21137
#                      Quarterphenyl-2NH (Adjacent)  0.0008928   0.197371
#                      Quarterphenyl-2NH (Across)    0.0009176   0.204513
#                      Quarterphenyl-3NH             0.0005828   0.194618
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2        0.0003968   0.098518
#
#                                                   Reorg Anion             \
#                                                      Low_freq   Mid_freq
# Molecular Group      Molecule
# Oligoacene           Benzene                                0  0.0005208
#                      Naphthalene                            0   0.262235
#                      Anthracene                     0.0567176   0.146122
#                      Tetracene                      0.0454088   0.119772
#                      Pentacene                      0.0364808  0.0984932
#                      Hexacene                       0.0302312  0.0824476
# Phenyls              Biphenyl                        0.012648   0.328501
#                      p-Terphenyl                    0.0073656   0.278454
#                      p-Quarterphenyl                0.0067332   0.241465
#                      p-Quinquephenyl                0.0047368   0.214706
#                      p-Sexiphenyl                    0.003472   0.191382
# Circulene            [5]circulene (corannulene)     0.0036332   0.223436
#                      [6]circulene (coronene)        0.0315084   0.142327
# Non-Cov Phenyls      Quarterphenyl                  0.0067332   0.241465
#                      Quarterphenyl-1NH               0.004588   0.288126
#                      Quarterphenyl-2NH (Adjacent)   0.0045012   0.290743
#                      Quarterphenyl-2NH (Across)     0.0041788    0.31558
#                      Quarterphenyl-3NH              0.0048608   0.281728
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2               NaN        NaN
#
#                                                                         \
#                                                    High_freq     Total
# Molecular Group      Molecule
# Oligoacene           Benzene                         0.12901   0.12953
#                      Naphthalene                    0.001674  0.263909
#                      Anthracene                    0.0016864  0.204526
#                      Tetracene                     0.0012648  0.166445
#                      Pentacene                     0.0012524  0.136226
#                      Hexacene                      0.0011656  0.113844
# Phenyls              Biphenyl                      0.0021204  0.343269
#                      p-Terphenyl                   0.0013144  0.287134
#                      p-Quarterphenyl               0.0010168  0.249215
#                      p-Quinquephenyl               0.0007316  0.220174
#                      p-Sexiphenyl                  0.0007068   0.19556
# Circulene            [5]circulene (corannulene)    0.0016492  0.228718
#                      [6]circulene (coronene)       0.0015252  0.175361
# Non-Cov Phenyls      Quarterphenyl                 0.0010168  0.249215
#                      Quarterphenyl-1NH             0.0010292  0.293744
#                      Quarterphenyl-2NH (Adjacent)   0.001054  0.296298
#                      Quarterphenyl-2NH (Across)    0.0008928  0.320652
#                      Quarterphenyl-3NH             0.0008432  0.287432
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2              NaN       NaN
#
#                                                     Reorg S1            ...  \
#                                                     Low_freq  Mid_freq  ...
# Molecular Group      Molecule                                           ...
# Oligoacene           Benzene                        3.72e-05  0.340789  ...
#                      Naphthalene                           0  0.572855  ...
#                      Anthracene                    0.0414408  0.400582  ...
#                      Tetracene                     0.0239072  0.330373  ...
#                      Pentacene                     0.0149048  0.277363  ...
#                      Hexacene                      0.0101308   0.24392  ...
# Phenyls              Biphenyl                      0.0826088   0.22635  ...
#                      p-Terphenyl                   0.0828072  0.216826  ...
#                      p-Quarterphenyl               0.0787896  0.195895  ...
#                      p-Quinquephenyl                0.015376  0.390302  ...
#                      p-Sexiphenyl                  0.0158968  0.375621  ...
# Circulene            [5]circulene (corannulene)          NaN       NaN  ...
#                      [6]circulene (coronene)             NaN       NaN  ...
# Non-Cov Phenyls      Quarterphenyl                 0.0787896  0.195895  ...
#                      Quarterphenyl-1NH             0.0142724  0.357418  ...
#                      Quarterphenyl-2NH (Adjacent)   0.119462   1.16388  ...
#                      Quarterphenyl-2NH (Across)      0.01798  0.435934  ...
#                      Quarterphenyl-3NH              0.104619    1.0752  ...
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2              NaN       NaN  ...
#
#                                                              \
#                                                       Total
# Molecular Group      Molecule
# Oligoacene           Benzene                       0.344435
#                      Naphthalene                   0.573698
#                      Anthracene                     0.44232
#                      Tetracene                     0.354355
#                      Pentacene                     0.292293
#                      Hexacene                      0.254064
# Phenyls              Biphenyl                       0.38037
#                      p-Terphenyl                   0.352371
#                      p-Quarterphenyl               0.323008
#                      p-Quinquephenyl               0.405889
#                      p-Sexiphenyl                  0.391691
# Circulene            [5]circulene (corannulene)         NaN
#                      [6]circulene (coronene)            NaN
# Non-Cov Phenyls      Quarterphenyl                 0.323008
#                      Quarterphenyl-1NH             0.372037
#                      Quarterphenyl-2NH (Adjacent)    1.2837
#                      Quarterphenyl-2NH (Across)    0.454051
#                      Quarterphenyl-3NH              1.18026
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2             NaN
#
#                                                   Molecule Background  \
#                                                               N_atoms
# Molecular Group      Molecule
# Oligoacene           Benzene                                       12
#                      Naphthalene                                   18
#                      Anthracene                                    24
#                      Tetracene                                     30
#                      Pentacene                                     36
#                      Hexacene                                      42
# Phenyls              Biphenyl                                      22
#                      p-Terphenyl                                   32
#                      p-Quarterphenyl                               42
#                      p-Quinquephenyl                               52
#                      p-Sexiphenyl                                  62
# Circulene            [5]circulene (corannulene)                    30
#                      [6]circulene (coronene)                       36
# Non-Cov Phenyls      Quarterphenyl                                 42
#                      Quarterphenyl-1NH                             40
#                      Quarterphenyl-2NH (Adjacent)                  38
#                      Quarterphenyl-2NH (Across)                    38
#                      Quarterphenyl-3NH                             36
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2                        57
#
#                                                                               \
#                                                   Molecular Mass Homo Energy
# Molecular Group      Molecule
# Oligoacene           Benzene                             78.0469    -6.83006
#                      Naphthalene                         128.063    -5.75412
#                      Anthracene                          178.078    -5.26976
#                      Tetracene                           228.094    -4.94513
#                      Pentacene                            278.11    -4.71601
#                      Hexacene                            328.125    -4.54729
# Phenyls              Biphenyl                            154.078    -5.91167
#                      p-Terphenyl                          230.11    -5.60282
#                      p-Quarterphenyl                     306.141    -5.45316
#                      p-Quinquephenyl                     382.172    -5.32173
#                      p-Sexiphenyl                        458.203    -5.27302
# Circulene            [5]circulene (corannulene)          250.078    0.751578
#                      [6]circulene (coronene)             300.094    0.858519
# Non-Cov Phenyls      Quarterphenyl                       306.141    -5.45316
#                      Quarterphenyl-1NH                   308.131    -5.57915
#                      Quarterphenyl-2NH (Adjacent)        310.122    -5.82623
#                      Quarterphenyl-2NH (Across)          310.122    -5.90569
#                      Quarterphenyl-3NH                   312.112    -5.87031
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2              950.279    -8.03688
#
#                                                                     \
#                                                   Molecular Energy
# Molecular Group      Molecule
# Oligoacene           Benzene                              -6321.26
#                      Naphthalene                          -10502.9
#                      Anthracene                           -14684.5
#                      Tetracene                            -18866.1
#                      Pentacene                            -23047.6
#                      Hexacene                             -27229.1
# Phenyls              Biphenyl                               -12610
#                      p-Terphenyl                          -18898.7
#                      p-Quarterphenyl                      -25187.5
#                      p-Quinquephenyl                      -31476.2
#                      p-Sexiphenyl                         -37764.9
# Circulene            [5]circulene (corannulene)           -20907.1
#                      [6]circulene (coronene)              -25091.8
# Non-Cov Phenyls      Quarterphenyl                        -25187.5
#                      Quarterphenyl-1NH                    -26060.7
#                      Quarterphenyl-2NH (Adjacent)         -26933.5
#                      Quarterphenyl-2NH (Across)           -26933.9
#                      Quarterphenyl-3NH                    -27806.8
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2               -47926.2
#
#                                                                               \
#                                                                Dipole Moment
# Molecular Group      Molecule
# Oligoacene           Benzene                                   [-0.  0.  0.]
#                      Naphthalene                               [ 0. -0.  0.]
#                      Anthracene                                [ 0.  0. -0.]
#                      Tetracene                                    [0. 0. 0.]
#                      Pentacene                                    [0. 0. 0.]
#                      Hexacene                                     [0. 0. 0.]
# Phenyls              Biphenyl                                  [-0.  0.  0.]
#                      p-Terphenyl                               [-0. -0. -0.]
#                      p-Quarterphenyl                           [-0. -0.  0.]
#                      p-Quinquephenyl                           [-0. -0.  0.]
#                      p-Sexiphenyl                              [-0.  0.  0.]
# Circulene            [5]circulene (corannulene)    [ 0.0098  0.0097 -0.    ]
#                      [6]circulene (coronene)                      [0. 0. 0.]
# Non-Cov Phenyls      Quarterphenyl                             [-0.  0.  0.]
#                      Quarterphenyl-1NH             [-0.     -0.     -0.7547]
#                      Quarterphenyl-2NH (Adjacent)  [ 0.      0.     -1.2686]
#                      Quarterphenyl-2NH (Across)    [-0.      0.     -0.3876]
#                      Quarterphenyl-3NH             [ 0.     -0.     -3.9184]
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2        [-2.3398 -0.731   0.    ]
#
#                                                                         \
#                                                   Excited State Energy
# Molecular Group      Molecule
# Oligoacene           Benzene                                       NaN
#                      Naphthalene                                   NaN
#                      Anthracene                                    NaN
#                      Tetracene                                     NaN
#                      Pentacene                                     NaN
#                      Hexacene                                      NaN
# Phenyls              Biphenyl                                      NaN
#                      p-Terphenyl                                   NaN
#                      p-Quarterphenyl                               NaN
#                      p-Quinquephenyl                               NaN
#                      p-Sexiphenyl                                  NaN
# Circulene            [5]circulene (corannulene)                    NaN
#                      [6]circulene (coronene)                       NaN
# Non-Cov Phenyls      Quarterphenyl                                 NaN
#                      Quarterphenyl-1NH                             NaN
#                      Quarterphenyl-2NH (Adjacent)                  NaN
#                      Quarterphenyl-2NH (Across)                    NaN
#                      Quarterphenyl-3NH                             NaN
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2                        NaN
#
#                                                                                                       \
#                                                                                  Oscillator Strength
# Molecular Group      Molecule
# Oligoacene           Benzene                                                                      []
#                      Naphthalene                   [7.4700e-02 1.0000e-04 0.0000e+00 1.2448e+00 0...
#                      Anthracene                    [5.8700e-02 2.0000e-04 0.0000e+00 0.0000e+00 0...
#                      Tetracene                     [4.6100e-02 0.0000e+00 1.9000e-03 0.0000e+00 0...
#                      Pentacene                     [3.6200e-02 0.0000e+00 0.0000e+00 5.8000e-03 0...
#                      Hexacene                      [2.800e-02 0.000e+00 0.000e+00 1.270e-02 0.000...
# Phenyls              Biphenyl                      [0.     0.     0.0034 0.     0.     0.1438 0.5...
#                      p-Terphenyl                   [0.0000e+00 3.0000e-04 0.0000e+00 0.0000e+00 1...
#                      p-Quarterphenyl               [0.0000e+00 0.0000e+00 0.0000e+00 3.0000e-04 0...
#                      p-Quinquephenyl               [2.230e+00 0.000e+00 0.000e+00 0.000e+00 0.000...
#                      p-Sexiphenyl                                                                 []
# Circulene            [5]circulene (corannulene)                                                  NaN
#                      [6]circulene (coronene)                                                     NaN
# Non-Cov Phenyls      Quarterphenyl                 [0.0000e+00 0.0000e+00 0.0000e+00 3.0000e-04 0...
#                      Quarterphenyl-1NH                                                            []
#                      Quarterphenyl-2NH (Adjacent)  [0.0000e+00 1.5815e+00 1.2000e-03 0.0000e+00 0...
#                      Quarterphenyl-2NH (Across)                                                   []
#                      Quarterphenyl-3NH             [0.0000e+00 0.0000e+00 1.6244e+00 1.3000e-03 0...
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2                                                      NaN
#
#                                                   Investigation
#                                                     Conjugation Non-Covalent
# Molecular Group      Molecule
# Oligoacene           Benzene                               True        False
#                      Naphthalene                           True        False
#                      Anthracene                            True        False
#                      Tetracene                             True        False
#                      Pentacene                             True        False
#                      Hexacene                              True        False
# Phenyls              Biphenyl                              True        False
#                      p-Terphenyl                           True        False
#                      p-Quarterphenyl                       True         True
#                      p-Quinquephenyl                       True        False
#                      p-Sexiphenyl                          True        False
# Circulene            [5]circulene (corannulene)            True        False
#                      [6]circulene (coronene)               True        False
# Non-Cov Phenyls      Quarterphenyl                        False         True
#                      Quarterphenyl-1NH                    False         True
#                      Quarterphenyl-2NH (Adjacent)         False         True
#                      Quarterphenyl-2NH (Across)           False         True
#                      Quarterphenyl-3NH                    False         True
# Phenothiazine-Pyrene Phenothiazine-Pyrene 2               False        False
#
# [19 rows x 21 columns]

# %%
Database.loc["Phenothiazine-Pyrene"]
# Out:
#                        Reorg Cation                                  \
#                            Low_freq   Mid_freq  High_freq     Total
# Molecule
# Phenothiazine-Pyrene 2     0.025172  0.0729492  0.0003968  0.098518
#
#                        Reorg Anion                          Reorg S1           \
#                           Low_freq Mid_freq High_freq Total Low_freq Mid_freq
# Molecule
# Phenothiazine-Pyrene 2         NaN      NaN       NaN   NaN      NaN      NaN
#
#                         ...       Molecule Background                 \
#                         ... Total             N_atoms Molecular Mass
# Molecule                ...
# Phenothiazine-Pyrene 2  ...   NaN                  57        950.279
#
#                                                      \
#                        Homo Energy Molecular Energy
# Molecule
# Phenothiazine-Pyrene 2    -8.03688         -47926.2
#
#                                                                         \
#                                     Dipole Moment Excited State Energy
# Molecule
# Phenothiazine-Pyrene 2  [-2.3398 -0.731   0.    ]                  NaN
#
#                                            Investigation
#                        Oscillator Strength   Conjugation Non-Covalent
# Molecule
# Phenothiazine-Pyrene 2                 NaN         False        False
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize=(15,6))
B = Database.loc["Phenyls"]["Reorg Cation"]["Mid_freq"]
C = Database.loc["Phenyls"]["Reorg Cation"]
#plt.bar(B.index, B)
#plt.bar(C.index, C)
C
# Out:
#                   Low_freq  Mid_freq  High_freq     Total
# Molecule
# Biphenyl          0.046934  0.216975  0.0010292  0.264938
# p-Terphenyl       0.047306  0.187686  0.0011408  0.236133
# p-Quarterphenyl  0.0472812  0.163841   0.000992  0.212114
# p-Quinquephenyl  0.0434744  0.144373  0.0010416  0.188889
# p-Sexiphenyl      0.040052  0.127832  0.0007812  0.168665

# %%
Database[Database["Molecule Background"]["Molecular Mass"]== Database["Molecule Background"]["Molecular Mass"].max()]
# Out:
#                              Reorg Cation                      Reorg Anion  \
#                                  Low_freq  Mid_freq  High_freq    Low_freq
# Molecular Group Molecule
# Phenyls         p-Sexiphenyl     0.040052  0.127832  0.0007812    0.003472
#
#                                                     Reorg S1            \
#                               Mid_freq  High_freq   Low_freq  Mid_freq
# Molecular Group Molecule
# Phenyls         p-Sexiphenyl  0.191382  0.0007068  0.0158968  0.375621
#
#                                         Molecule Background                 \
#                               High_freq             N_atoms Molecular Mass
# Molecular Group Molecule
# Phenyls         p-Sexiphenyl  0.0001736                  62        458.203
#
#                                                                           \
#                              Homo Energy Molecular Energy  Dipole Moment
# Molecular Group Molecule
# Phenyls         p-Sexiphenyl    -5.27302         -37764.9  [-0.  0.  0.]
#
#                              Investigation
#                                Conjugation Non-Covalent
# Molecular Group Molecule
# Phenyls         p-Sexiphenyl          True        False

# %% [markdown]
# ## Some documentation
#
# ### Units:
# - All Energies are in eVs.
#
# - Molecular masses are in Daltons
#
# - Dipole Moments are in a.u.
#
# ### Other:
# The molecular energy is the energy of the right most calculated state. (Excited overwrites Anion overwrites Cation)

# %%
cmtoEv = 1.24e-4
a = pd.read_csv('Reorg_Energy/conjugated_carbonyls_0_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
b = pd.read_csv('Reorg_Energy/conjugated_carbonyls_1_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
c = pd.read_csv('Reorg_Energy/conjugated_carbonyls_2_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
d = pd.read_csv('Reorg_Energy/conjugated_carbonyls_3_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv

anion_energy = [a,b,c,d]
names = ["PTO", "PhenQ", "BDTQ", "BQ"]
plt.bar(names, anion_energy)
plt.ylabel("Anion reorg energy (eV)")
plt.title("-1 to -2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-49-869d30401f4e> in <module>
#       1 cmtoEv = 1.24e-4
# ----> 2 a = pd.read_csv('Reorg_Energy/conjugated_carbonyls_0_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
#       3 b = pd.read_csv('Reorg_Energy/conjugated_carbonyls_1_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
#       4 c = pd.read_csv('Reorg_Energy/conjugated_carbonyls_2_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
#       5 d = pd.read_csv('Reorg_Energy/conjugated_carbonyls_3_C-2S0_C-3S0')["Reorg Energy"].sum()*cmtoEv
#
# ~/anaconda3/envs/Bsc_Project/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/envs/Bsc_Project/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/envs/Bsc_Project/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/anaconda3/envs/Bsc_Project/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~/anaconda3/envs/Bsc_Project/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Reorg_Energy/conjugated_carbonyls_0_C-2S0_C-3S0'
